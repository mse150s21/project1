# %%
import numpy
import matplotlib.pyplot as plt

a = numpy.loadtxt('samples/1.raw',skiprows=1,delimiter=',')

# %%
plt.plot(a[:,0],a[:,1])

# %%
matplotlib inline

# %%
plt.plot(a[:,0],a[:,1])
stop = 12
x = a[:stop,0]
y = a[:stop,1]
a = numpy.loadtxt('samples/1.raw',skiprows=1,delimiter=',')
a_1, a_0 = numpy.polyfit(x,y,1)
fit = numpy.poly1d((a_1,a_0))
plt.plot(a[:stop,0],fit(a[:stop,0]))

# %%
stop = 10
x = a[:stop,0]
y = a[:stop,1]
a = numpy.loadtxt('samples/2.raw',skiprows=1,delimiter=',')
plt.plot(a[:,0],a[:,1])
a_1, a_0 = numpy.polyfit(x,y,1)
print(a_1)
fit = numpy.poly1d((a_1,a_0))
plt.plot(a[:stop,0],fit(a[:stop,0]))
# Out:
# 4227107.5145035945

# %%
b = numpy.loadtxt('samples/2.raw',skiprows=1,delimiter=',')
len(b)
# Out:
# 120
